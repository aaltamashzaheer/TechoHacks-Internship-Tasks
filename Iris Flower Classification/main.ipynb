# %% [markdown]
# # Machine Learning Project No 1: Iris Flower Classification

# %% [markdown]
# # Reading CSV

# %%
import pandas as pd
df=pd.read_csv('Iris.csv')
df.head()
# Out:
#    sepalLengthCm  sepalWidthCm  petalLengthCm  petalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Tells about some basic statistic operations

# %%
df.describe()
# Out:
#        sepalLengthCm  sepalWidthCm  petalLengthCm  petalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # Generic Info of Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   sepalLengthCm  150 non-null    float64
#  1   sepalWidthCm   150 non-null    float64
#  2   petalLengthCm  150 non-null    float64
#  3   petalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # Tells about different Categories within one column

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # Histogram of Columns

# %%
df['sepalLengthCm'].hist()
# Out:
# <Axes: >

# %%
df['sepalWidthCm'].hist()
# Out:
# <Axes: >

# %%
df['petalLengthCm'].hist()
# Out:
# <Axes: >

# %%
df['petalWidthCm'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # Relations between two columns

# %%
import matplotlib.pyplot as plt
colors=['red','orange','blue']
Species=['Iris-virginica','Iris-setosa','Iris-versicolor']
for i in range (3):
    x=df[df['Species']==Species[i]]
    plt.scatter(x['sepalLengthCm'],x['sepalWidthCm'],c=colors[i],label=Species[i])
    plt.xlabel("Sepal Length")
    plt.ylabel("Sepal Width")
    plt.legend()

# %%
for i in range (3):
    x=df[df['Species']==Species[i]]
    plt.scatter(x['petalLengthCm'],x['petalWidthCm'],c=colors[i],label=Species[i])
    plt.xlabel("Petal Length")
    plt.ylabel("Petal Width")
    plt.legend()

# %%
for i in range (3):
    x=df[df['Species']==Species[i]]
    plt.scatter(x['petalLengthCm'],x['sepalWidthCm'],c=colors[i],label=Species[i])
    plt.xlabel("Petal Length")
    plt.ylabel("Petal Width")
    plt.legend()

# %% [markdown]
# # Heatmap of Correlation between one Coulmn to other

# %%
import seaborn as sns
import numpy as np
columns = df.select_dtypes(include=np.number)
corr= columns.corr()
fig,ax=plt.subplots(figsize=(5,4))
sns.heatmap(corr,annot=True,ax=ax,cmap='coolwarm')
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Species']=le.fit_transform(df['Species'])
df.head()
# Out:
#    sepalLengthCm  sepalWidthCm  petalLengthCm  petalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %% [markdown]
# # Model Training and Accuracy Percentage Check

# %% [markdown]
# ## Logistic Regression Model

# %%
from sklearn.model_selection import train_test_split
x=df.drop(columns=['Species'])
y=df['Species']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)

from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
prediction=model.predict([[7,4,6.5,2.5]])
print(prediction)
print('Accuracy of Model is: ', model.score(x_train,y_train)*100)
# Out:
# [2]
# Accuracy of Model is:  99.04761904761905
# c:\Users\Sigma Male\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ##  Knn Model

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()
model.fit(x_train,y_train)
prediction=model.predict([[7,4,6.5,2.5]])
print(prediction)
print('Accuracy of Model is: ', model.score(x_train,y_train)*100)
# Out:
# [2]
# Accuracy of Model is:  99.04761904761905
# c:\Users\Sigma Male\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Desicion Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
prediction=model.predict([[7,4,6.5,2.5]])
print(prediction)
print('Accuracy of Model is: ', model.score(x_train,y_train)*100)
# Out:
# [2]
# Accuracy of Model is:  100.0
# c:\Users\Sigma Male\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
